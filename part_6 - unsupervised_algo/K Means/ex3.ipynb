# %%
from sklearn.datasets import make_moons

# %%
x,y=make_moons(n_samples=1000,noise=0.1)

# %%
import matplotlib.pyplot as plt
plt.scatter(x[:,0],x[:,1])

# %%
?
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from sklearn.cluster import train_test_split
#       2 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)
#
# ImportError: cannot import name 'train_test_split' from 'sklearn.cluster' (C:\Program Files\Anaconda\Lib\site-packages\sklearn\cluster\__init__.py)

# %%
from sklearn.cluster import DBSCAN
DBSCAN
